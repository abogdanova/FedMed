# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Train Loss for Different Frequency of Communication Rounds

# %%
loss_non_fed = [0.046573911333084105]
loss_fed_E1 = [1.9355303, 1.6790457, 1.5591009, 1.4617914, 1.377197, 1.2985498, 1.2302358, 1.1683689, 1.113773, 1.0633456, 1.015893, 0.9731998]
loss_fed_E2 = [1.7114248, 1.3747084, 1.1848909, 1.0470626, 0.93492013, 0.83904773]
loss_fed_E3 = [1.6074595, 1.2174757, 0.9774349, 0.7979303]
loss_fed_E4 = [1.4678867, 0.9663875, 0.6975385]
loss_fed_E6 = [1.3024889, 0.68840617]
loss_fed_E12 = [0.86730546]

# %%
plt.plot(loss_non_fed, color="grey",  marker='*', markersize = 12, label="Non-federated")
plt.plot(loss_fed_E1, marker='o', label='E-1', markersize = 2)
plt.plot(loss_fed_E2, marker='o', label='E-1', markersize = 4)
plt.plot(loss_fed_E3, marker='o', label='E-1', markersize = 6)
plt.plot(loss_fed_E4, marker='o', label='E-4', markersize = 8)
plt.plot(loss_fed_E6, marker='o', label='E-6', markersize = 10)
plt.plot(loss_fed_E12, 'co-', label='E-12', markersize=12)
plt.ylabel('Train Loss')
plt.xlabel('Communication Rounds')
plt.title("CIFAR10 IID")
plt.legend()
plt.show()

# %% [markdown]
# # Test Accuracy for Different Frequency of Communication Rounds

# %%
acc_non_fed = [0.3597]
acc_fed_E1 = [0.4244, 0.464, 0.4862, 0.5145, 0.5314, 0.5511, 0.5683, 0.5761, 0.5857, 0.5909, 0.5944, 0.5945]
acc_fed_E2 = [0.4805, 0.5256, 0.5585, 0.5746, 0.5807, 0.5821]
acc_fed_E3 = [0.4912, 0.549, 0.5739, 0.5767]
acc_fed_E4 = [0.5192, 0.5696, 0.58]
acc_fed_E6 = [0.5381, 0.5746]
acc_fed_E12 = [0.536]

# %%
plt.plot(acc_non_fed, color="grey",  marker='*', markersize = 12, label="Non-federated")
plt.plot(acc_fed_E1, marker='o', label='E-1', markersize = 2)
plt.plot(acc_fed_E2, marker='o', label='E-1', markersize = 4)
plt.plot(acc_fed_E3, marker='o', label='E-1', markersize = 6)
plt.plot(acc_fed_E4, marker='o', label='E-4', markersize = 8)
plt.plot(acc_fed_E6, marker='o', label='E-6', markersize = 10)
plt.plot(acc_fed_E12, 'co-', label='E-12', markersize=12)
plt.ylabel('Test Accuracy')
plt.xlabel('Communication Rounds')
plt.title("CIFAR10 IID")
plt.legend()
plt.show()
