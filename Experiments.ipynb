# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Non-federated data - CIFAR10
NFTrain = [None, 1.6744487216949462, 1.3088731965065001, 1.111428643989563, 0.9623309387207031, 
           0.8364500361442566, 0.6936232349395752, 0.5654297759532928, 0.41290901288986204, 
           0.29217336299419405, 0.1931610435962677, 0.11122871858477593, 0.05975285329222679]
NFTest = [None, 1.462911502456665, 1.2925301193237304, 1.216324380493164, 1.219829660797119, 
          1.2312662796020508, 1.2178772827148439, 1.3155008291244508, 1.3661239205360414, 
          1.424590300655365, 1.4774989210128784, 1.5656848281860352, 1.6493133316040038]
NFAccuracy = [None, 0.4793, 0.5491, 0.5767, 0.5789, 0.5863, 0.5986, 0.5812, 0.5825, 0.596, 0.5933, 0.5961, 0.5947]

# %%
# Federated data (5 users), iid, CIFAR10
iE1C5Train = [None, 1.9009285, 1.6381454, 1.5189072, 1.4270283, 1.3469105, 
1.2733163, 1.2062289, 1.1480272, 1.0960802, 1.0492746, 1.0058247,
0.96338713] 
iE1C5Test = [None, 1.9009285, 1.6381454, 1.5189072, 1.4270283,
1.3469105, 1.2733163, 1.2062289, 1.1480272, 1.0960802, 1.0492746,
1.0058247, 0.96338713] 
iE1C5Accuracy = [None, 0.4386, 0.4788, 0.5025, 0.5241,
0.5452, 0.5569, 0.5662, 0.5751, 0.5786, 0.5836, 0.5867, 0.5869]

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(NFTrain, color="grey",  marker='*', markersize = 2, label="Non-federated")
plt.plot(iE1C5Train, marker='o', label='E-1', markersize = 2)
plt.xticks(np.arange(1, 13, step=1))
plt.ylabel('Train Loss')
plt.xlabel('Communication Rounds')
plt.title("CIFAR10 IID")
plt.legend(ncol=2)

plt.subplot(1,2,2)
plt.plot(NFTest, color="grey",  marker='*', markersize = 2, label="Non-federated")
plt.plot(iE1C5Test, marker='o', label='E-1', markersize = 2)
plt.xticks(np.arange(1, 13, step=1))
plt.ylabel('Test Loss')
plt.xlabel('Communication Rounds')
plt.title("CIFAR10 IID")
plt.legend(ncol=2)

plt.show()
